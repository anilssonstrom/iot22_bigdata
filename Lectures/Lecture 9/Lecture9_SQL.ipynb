# %%
sc = spark.sparkContext.getOrCreate()

# %%
df1 = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/andreas.nilssonstrom@kyh.se/titanic-1.csv")
df1.createOrReplaceTempView('titanic')

# %%
df1.show(8)
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|          Ticket|   Fare|Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |          1|       0|     3|Braund, Mr. Owen ...|  male|  22|    1|    0|       A/5 21171|   7.25| null|       S|
# |          2|       1|     1|Cumings, Mrs. Joh...|female|  38|    1|    0|        PC 17599|71.2833|  C85|       C|
# |          3|       1|     3|Heikkinen, Miss. ...|female|  26|    0|    0|STON/O2. 3101282|  7.925| null|       S|
# |          4|       1|     1|Futrelle, Mrs. Ja...|female|  35|    1|    0|          113803|   53.1| C123|       S|
# |          5|       0|     3|Allen, Mr. Willia...|  male|  35|    0|    0|          373450|   8.05| null|       S|
# ...

# %%
df1.filter(df1.Sex == 'male').select(['Name', 'Sex', 'Survived']).show(5)
# Out:
# +--------------------+----+--------+
# |                Name| Sex|Survived|
# +--------------------+----+--------+
# |Braund, Mr. Owen ...|male|       0|
# |Allen, Mr. Willia...|male|       0|
# |    Moran, Mr. James|male|       0|
# |McCarthy, Mr. Tim...|male|       0|
# |Palsson, Master. ...|male|       0|
# +--------------------+----+--------+
# only showing top 5 rows

# %%
spark.sql('SELECT Name, Sex, Survived FROM titanic WHERE Sex = "male"').show(5)
# Out:
# +--------------------+----+--------+
# |                Name| Sex|Survived|
# +--------------------+----+--------+
# |Braund, Mr. Owen ...|male|       0|
# |Allen, Mr. Willia...|male|       0|
# |    Moran, Mr. James|male|       0|
# |McCarthy, Mr. Tim...|male|       0|
# |Palsson, Master. ...|male|       0|
# +--------------------+----+--------+
# only showing top 5 rows
